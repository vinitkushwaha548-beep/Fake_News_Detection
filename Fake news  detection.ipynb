# %% [markdown]
# Fake News Detection
# ###  import library

# %%
import pandas as pd
import numpy as np
import itertools

# %%
df=pd.read_csv("news.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
df.shape
# Out:
# (6335, 4)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# title         0
# text          0
# label         0
# dtype: int64

# %%
labels = df.label

# %%
labels
# Out:
# 0       FAKE
# 1       FAKE
# 2       REAL
# 3       FAKE
# 4       REAL
#         ...
# 6330    REAL
# 6331    FAKE
# 6332    FAKE
# 6333    REAL
# 6334    REAL
# Name: label, Length: 6335, dtype: str

# %%
# !pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.9.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in .\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (2.5.0)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl.metadata (61 kB)
# Collecting joblib>=1.4.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn)
#   Downloading narwhals-2.23.0-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.9.0-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.3 MB 1.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.3 MB 2.0 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.3 MB 1.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.3 MB 2.0 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.4/8.3 MB 2.1 MB/s eta 0:00:03
#    ------------- -------------------------- 2.9/8.3 MB 2.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.4/8.3 MB 2.1 MB/s eta 0:00:03
#    ------------------ --------------------- 3.9/8.3 MB 2.1 MB/s eta 0:00:03
#    --------------------- ------------------ 4.5/8.3 MB 2.2 MB/s eta 0:00:02
#    ------------------------ --------------- 5.0/8.3 MB 2.2 MB/s eta 0:00:02
#    ------------------------- -------------- 5.2/8.3 MB 2.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 6.0/8.3 MB 2.2 MB/s eta 0:00:02
#    ------------------------------- -------- 6.6/8.3 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.3 MB 2.3 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.3 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.3 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 2.3 MB/s  0:00:03
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.23.0-py3-none-any.whl (458 kB)
# Downloading scipy-1.18.0-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#     --------------------------------------- 0.5/37.3 MB 2.6 MB/s eta 0:00:15
#    - -------------------------------------- 1.0/37.3 MB 3.0 MB/s eta 0:00:12
#    - -------------------------------------- 1.3/37.3 MB 2.4 MB/s eta 0:00:16
#    -- ------------------------------------- 2.1/37.3 MB 2.6 MB/s eta 0:00:14
#    -- ------------------------------------- 2.6/37.3 MB 2.6 MB/s eta 0:00:14
#    --- ------------------------------------ 3.1/37.3 MB 2.6 MB/s eta 0:00:13
#    --- ------------------------------------ 3.7/37.3 MB 2.7 MB/s eta 0:00:13
#    ---- ----------------------------------- 4.5/37.3 MB 2.8 MB/s eta 0:00:12
#    ----- ---------------------------------- 5.2/37.3 MB 2.8 MB/s eta 0:00:12
#    ------ --------------------------------- 5.8/37.3 MB 2.8 MB/s eta 0:00:12
#    ------ --------------------------------- 6.3/37.3 MB 2.9 MB/s eta 0:00:11
#    ------- -------------------------------- 7.1/37.3 MB 2.9 MB/s eta 0:00:11
#    -------- ------------------------------- 7.6/37.3 MB 2.9 MB/s eta 0:00:11
#    --------- ------------------------------ 8.7/37.3 MB 3.0 MB/s eta 0:00:10
#    ---------- ----------------------------- 9.4/37.3 MB 3.1 MB/s eta 0:00:10
#    ---------- ----------------------------- 10.0/37.3 MB 3.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 10.7/37.3 MB 3.1 MB/s eta 0:00:09
#    ------------ --------------------------- 11.8/37.3 MB 3.2 MB/s eta 0:00:08
#    ------------- -------------------------- 12.3/37.3 MB 3.2 MB/s eta 0:00:08
#    -------------- ------------------------- 13.1/37.3 MB 3.2 MB/s eta 0:00:08
#    -------------- ------------------------- 13.9/37.3 MB 3.3 MB/s eta 0:00:08
#    ---------------- ----------------------- 14.9/37.3 MB 3.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 15.7/37.3 MB 3.4 MB/s eta 0:00:07
#    ----------------- ---------------------- 16.5/37.3 MB 3.4 MB/s eta 0:00:07
#    ------------------ --------------------- 17.6/37.3 MB 3.4 MB/s eta 0:00:06
#    ------------------- -------------------- 18.4/37.3 MB 3.5 MB/s eta 0:00:06
#    --------------------- ------------------ 19.7/37.3 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 20.7/37.3 MB 3.6 MB/s eta 0:00:05
#    ----------------------- ---------------- 21.8/37.3 MB 3.7 MB/s eta 0:00:05
#    ------------------------ --------------- 22.8/37.3 MB 3.7 MB/s eta 0:00:04
#    ------------------------- -------------- 23.9/37.3 MB 3.8 MB/s eta 0:00:04
#    ------------------------- -------------- 24.1/37.3 MB 3.7 MB/s eta 0:00:04
#    -------------------------- ------------- 25.2/37.3 MB 3.7 MB/s eta 0:00:04
#    ---------------------------- ----------- 26.2/37.3 MB 3.7 MB/s eta 0:00:03
#    ---------------------------- ----------- 26.7/37.3 MB 3.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.3/37.3 MB 3.7 MB/s eta 0:00:03
#    ----------------------------- ---------- 27.8/37.3 MB 3.7 MB/s eta 0:00:03
#    ------------------------------ --------- 28.3/37.3 MB 3.6 MB/s eta 0:00:03
#    ------------------------------ --------- 28.8/37.3 MB 3.6 MB/s eta 0:00:03
#    ------------------------------- -------- 29.4/37.3 MB 3.6 MB/s eta 0:00:03
#    -------------------------------- ------- 29.9/37.3 MB 3.6 MB/s eta 0:00:03
#    -------------------------------- ------- 30.7/37.3 MB 3.5 MB/s eta 0:00:02
#    --------------------------------- ------ 31.5/37.3 MB 3.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.0/37.3 MB 3.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 32.5/37.3 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 33.3/37.3 MB 3.5 MB/s eta 0:00:02
#    ------------------------------------ --- 33.8/37.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 34.6/37.3 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 35.4/37.3 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 35.9/37.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  36.7/37.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 3.4 MB/s  0:00:10
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, narwhals, joblib, scikit-learn
#
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    -------- ------------------------------- 1/5 [scipy]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ---------------- ----------------------- 2/5 [narwhals]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    ------------------------ --------------- 3/5 [joblib]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    -------------------------------- ------- 4/5 [scikit-learn]
#    ---------------------------------------- 5/5 [scikit-learn]
#
# Successfully installed joblib-1.5.3 narwhals-2.23.0 scikit-learn-1.9.0 scipy-1.18.0 threadpoolctl-3.6.0
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: C:\Users\INDIAN\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %% [markdown]
# import sklearn

# %%
print(sklearn.__version__)
# Out:
# 1.9.0

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train,y_test= train_test_split(df["text"],labels,test_size=0.2,random_state=20)

# %%
x_train.head()
# Out:
# 4741    NAIROBI, Kenya — President Obama spoke out Sun...
# 2089    Killing Obama administration rules, dismantlin...
# 4074    Dean Obeidallah, a former attorney, is the hos...
# 5376      WashingtonsBlog \nCNN’s Jake Tapper hit the ...
# 6028    Some of the biggest issues facing America this...
# Name: text, dtype: str

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier

# %%
 #Initilise a TfidfVectorizer
vector = TfidfVectorizer(stop_words='english', max_df=0.7)

# %%
# fit and trasnsform
tf_train = vector.fit_transform(x_train)
tf_test = vector.transform(x_test)

# %%
# initilise a PassiveAggressiveClassifier
pac= PassiveAggressiveClassifier(max_iter=50)
pac.fit(tf_train, y_train)
# Out:
# C:\Users\INDIAN\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\deprecation.py:71: FutureWarning: Class PassiveAggressiveClassifier is deprecated; this is deprecated in version 1.8 and will be removed in 1.10. Use `SGDClassifier(loss='hinge', penalty=None, learning_rate='pa1', eta0=1.0)` instead.
#   warnings.warn(msg, category=FutureWarning)
# PassiveAggressiveClassifier(max_iter=50)

# %%
# prediction the 1st dataset
from sklearn.metrics import accuracy_score, confusion_matrix
y_pred =pac.predict(tf_test)

# %%
score=accuracy_score(y_test,y_pred)

# %%
print(f"Accuracy : {round(score*100,2)}%")
# Out:
# Accuracy : 94.95%

# %%
# confusion metrics
confusion_matrix(y_test,y_pred, labels=['FAKE' , 'REAL'])
# Out:
# array([[622,  26],
#        [ 38, 581]])

# %%
# save model
import pickle
filename = 'finalized_model.pkl'
pickle.dump(pac, open(filename, 'wb'))
